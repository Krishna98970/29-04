# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishna98970/29-04/blob/master/Visualisation_Handson_16_07_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Dataset Link:https://drive.google.com/file/d/1evN-4mczivkILdN7wem1T5hxJB4yPuRi/view?usp=sharing

# %%
df=pd.read_csv('/content/Cars (1).csv',skipinitialspace=True)

# %%
df
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 0    14.0          8        350.0  165     4209.0          12  1972      US.
# 1    31.9          4         89.0   71     1925.0          14  1980  Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971      US.
# 3    15.0          8        400.0  150     3761.0          10  1971      US.
# 4    30.5          4         98.0   63     2051.0          17  1978      US.
# ..    ...        ...          ...  ...        ...         ...   ...      ...
# 256  17.0          8        305.0  130     3840.0          15  1980      US.
# 257  36.1          4         91.0   60     1800.0          16  1979   Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983      US.
# 259  18.0          6        232.0  100     3288.0          16  1972      US.
# 260  22.0          6        250.0  105     3353.0          15  1977      US.
#
# [261 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %% [markdown]
# Create scatter plot for the following data,make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.
#
# (mpg-hp,mpg-weight) and (hp-mpg,hp-time-to-60) with respect to brand.

# %%
fig=plt.subplots(2,2,figsize=(20,10))
plt.subplot(2,2,1)   #plot-1
sns.scatterplot(x=df['mpg'],y=df['hp'],data=df,hue=df['brand'])
plt.xlabel('MPG')
plt.ylabel('HP')
plt.title('MPG VS HP')

plt.subplot(2,2,2)   #plot-2
sns.scatterplot(x=df['mpg'],y=df['weightlbs'],data=df,hue=df['brand'])
plt.xlabel('MPG')
plt.ylabel('Weight')
plt.title('MPG VS Weight')

plt.subplot(2,2,3)   #plot-3
sns.scatterplot(x=df['hp'],y=df['mpg'],data=df,hue=df['brand'])
plt.xlabel('HP')
plt.ylabel('MPG')
plt.title('HP VS MPG')

plt.subplot(2,2,4)   #plot-4
sns.scatterplot(x=df['hp'],y=df['time-to-60'],data=df,hue=df['brand'])
plt.xlabel('HP')
plt.ylabel('Time-to-60')
plt.title('HP VS Time-to-60')
# Out:
# Text(0.5, 1.0, 'HP VS Time-to-60')

# %% [markdown]
# Create barplots for the following ,make sure all the plots appear in the same plane with xlabel and y label evenly spaced.
#
# hp,mpg,weight,time-to-60 with respect to brand and to the number of cylinders.
#
# hp vs cylinders
#
# mpg vs cylinders
#
# weight vs cylinders
#
# time-to-60 vs cylinders

# %%
fig=plt.subplots(2,2,figsize=(10,10))
plt.subplot(2,2,1)
sns.barplot(data=df,x='cylinders',y='hp',hue='brand')
plt.xlabel('Cylinders')
plt.ylabel('HP')

plt.subplot(2,2,2)
sns.barplot(data=df,x='cylinders',y='mpg',hue='brand')
plt.xlabel('Cylinders')
plt.ylabel('MPG')

plt.subplot(2,2,3)
sns.barplot(data=df,x='cylinders',y='weightlbs',hue='brand')
plt.xlabel('Cylinders')
plt.ylabel('Weight')

plt.subplot(2,2,4)
sns.barplot(data=df,x='cylinders',y='time-to-60',hue='brand')
plt.xlabel('Cylinders')
plt.ylabel('Time-to-60')
# Out:
# Text(0, 0.5, 'Time-to-60')

# %% [markdown]
# Create a box-plot for the following with repect to brand:
#
# hp vs cylinder
#
# mpg vs cylinder
#
# weight vs cylinder
#
# time-to-60 vs cylinder

# %%
#10:28

# %%
fig = plt.subplots(2,2,figsize = (20,10))
plt.subplot(2,2,1)
sns.boxplot(x='cylinders', y='hp', data = df, hue = df.brand)
plt.xlabel('HP')
plt.ylabel('CYLENDERS')
plt.title('HP VS CYLENDERS')
plt.subplot(2,2,2)
sns.boxplot(x=df.cylinders, y=df.mpg, data = df, hue = df.brand)
plt.xlabel('MPG')
plt.ylabel('CYLENDERS')
plt.title('MPG VS CYLENDERS')
plt.subplot(2,2,3)
sns.boxplot(x=df.cylinders, y=df.weightlbs, data = df, hue = df.brand)
plt.xlabel('WEIGHT')
plt.ylabel('CYLENDERS')
plt.title('WEIGHT VS CYLENDERS')
plt.subplot(2,2,4)
sns.boxplot(x=df.cylinders, y=df['time-to-60'], data = df, hue = df.brand)
plt.xlabel('TIME-TO-60')
plt.ylabel('CYLENDERS')
plt.title('TIME-TO-60 VS CYLENDERS')
plt.show()

# %% [markdown]
# Create a histogram for the following:
# hp,mpg,time-to-60,weight,cubicinches,year with respect to brand.Make sure to plot all the plots in the same plane with x and y label evenly spaced.

# %%
fig=plt.subplots(3,2,figsize=(20,20))
plt.subplot(3,2,1)
sns.histplot(data=df,x='hp',hue='brand')
plt.xlabel('HP')

plt.subplot(3,2,2)
sns.histplot(data=df,x='mpg',hue='brand')
plt.xlabel('MPG')

plt.subplot(3,2,3)
sns.histplot(data=df,x='time-to-60',hue='brand')
plt.xlabel('Time-to-60')

plt.subplot(3,2,4)
sns.histplot(data=df,x='weightlbs',hue='brand')
plt.xlabel('Weight')

plt.subplot(3,2,5)
sns.histplot(data=df,x='cubicinches',hue='brand')
plt.xlabel('Cubicinches')

plt.subplot(3,2,6)
sns.histplot(data=df,x='year',hue='brand')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# Create a heatmap for the entire data to study the correlation between each of the columns.

# %%
numData=df.select_dtypes(include=[float,int])
corrMat=numData.corr()
corrMat
# Out:
#                   mpg  cylinders  cubicinches        hp  weightlbs  \
# mpg          1.000000  -0.776710    -0.803964 -0.774905  -0.825234
# cylinders   -0.776710   1.000000     0.951452  0.845155   0.896093
# cubicinches -0.803964   0.951452     1.000000  0.906902   0.930027
# hp          -0.774905   0.845155     0.906902  1.000000   0.861028
# weightlbs   -0.825234   0.896093     0.930027  0.861028   1.000000
# time-to-60   0.509070  -0.578161    -0.613199 -0.744873  -0.480772
# year         0.550441  -0.322239    -0.350293 -0.383869  -0.281119
#
#              time-to-60      year
# mpg            0.509070  0.550441
# cylinders     -0.578161 -0.322239
# cubicinches   -0.613199 -0.350293
# hp            -0.744873 -0.383869
# weightlbs     -0.480772 -0.281119
# time-to-60     1.000000  0.312311
# year           0.312311  1.000000

# %%
sns.heatmap(corrMat,annot=True,linewidths=2,cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# Create a pie chart for Brand columns with three total value frequency

# %%
x=df['brand'].value_counts()

# %%
x
# Out:
# brand
# US.        162
# Japan.      51
# Europe.     48
# Name: count, dtype: int64

# %%
162+51+48
# Out:
# 261

# %%
162/261*100
# Out:
# 62.06896551724138

# %%
51/261*100
# Out:
# 19.54022988505747

# %%
48/261*100
# Out:
# 18.39080459770115

# %%
x.plot.pie(autopct='%.2f%%')
plt.show()

# %%
df=sns.load_dataset('diamonds')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# Q1. How does the diamond carat effect its price?(scatter plot)
#
# Q2.Which diamond cut has the highest average price?(bar plot)

# %%
#How does the diamond carat effect its price?(scatter plot)
sns.scatterplot(x='carat',y='price',data=df)
plt.title('Carat Vs Price')
plt.show()

# %% [markdown]
# Inferences:
#
# As carat increases price also increases.
# This means larger diamonds will be costly.
#
# Most diamonds in the dataset are samll to medium in size and price.

# %%
#Which diamond cut has the highest average price?(bar plot)
sns.barplot(x='cut',y='price',data=df)
plt.title('Average price by cut')
plt.show()

# %% [markdown]
# Inferences:
#
# premium diamonds has highest avg prices.
#
# ideal cut even though it is the best quality has a lower average price.

# %% [markdown]
# How are carat values distrbuted?(Histogram)
#
# What is the range and also find out that there is an oulier or not for each diamond cut?(Box plot)
#
# Which feature are most related to diamond price?(heatmap)
#
# How is carat spread accross different cuts?(violin plot)
#
# Count of diamonds by cut?(pie chart)

# %%
#Homework
